# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/Users/mmorg27/Downloads/VOC/meta_Toys_and_Games.csv')
# Out:
# /var/folders/0j/nxqq7fj522jd7mhxrp7nyth826qpyw/T/ipykernel_91117/1348232073.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/mmorg27/Downloads/VOC/meta_Toys_and_Games.csv')

# %%
display(df.head(5))
unique_names = df['brand'].unique()


for name in unique_names:
    if isinstance(name, str) and 'hasbro' in name.lower():
        df.loc[df['brand'].str.lower() == name.lower(), 'brand'] = 'Hasbro'

# Now 'hasbro' in any case in the 'brand' column has been replaced with 'Hasbro'


# Creating a new DataFrame containing rows where brand is "Hasbro"
hasbro_df = df[df['brand'].str.lower() == 'hasbro']
# Out:
#                                         category tech1  \
# 0  ['Toys & Games', 'Puzzles', 'Jigsaw Puzzles']   NaN
# 1                                             []   NaN
# 2                                             []   NaN
# 3        ['Toys & Games', 'Games', 'Card Games']   NaN
# 4                                             []   NaN
#
#                                          description  fit  \
# 0  ["Three Dr. Suess' Puzzles: Green Eggs and Ham...  NaN
# 1  ['<b>Prepare to be Afraid!</b><br /><br />The ...  NaN
# 2                                                 []  NaN
# 3                        ['Blitz Vintage Card Game']  NaN
# 4  ['Marvel SuperHeroes themed "magic ink" colori...  NaN
#
#                                             title  \
# 0  Dr. Suess 19163 Dr. Seuss Puzzle 3 Pack Bundle
# 1     Pathfinder: Book of Beasts - Legendary Foes
# 2                        Nursery Rhymes Felt Book
# 3                           Dutch Blitz Card Game
# 4        Magic Pen Painting (Marvel Super Heroes)
#
#                        also_buy tech2  \
# 0                            []   NaN
# 1                            []   NaN
# 2                            []   NaN
# 3                ['B00WIIPQEC']   NaN
# 4  ['B009SB7TI8', 'B009SB8Z1I']   NaN
#
#                                            brand  \
# 0                                      Dr. Seuss
# 1  Pathfinder Roleplaying Jon Brazer Productions
# 2                                   Betty Lukens
# 3                           Dutch Blitz Games Co
# 4                               Lee Publications
#
#                                              feature  \
# 0  ['Three giant floor puzzles', 'Includes: Dr. S...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                                 rank  \
# 0  ['>#2,230,717 in Toys & Games (See Top 100 in ...
# 1  ['>#2,294,535 in Toys & Games (See Top 100 in ...
# 2  ['>#2,871,983 in Toys & Games (See Top 100 in ...
# 3  ['>#376,337 in Toys & Games (See Top 100 in To...
# 4  ['>#934,954 in Toys & Games (See Top 100 in To...
#
#                                            also_view      main_cat  \
# 0                                                 []  Toys & Games
# 1                                                 []  Toys & Games
# 2                                                 []  Toys & Games
# 3  ['B000BBU0KS', 'B00NQQTZ5G', 'B00WIIPQEC', 'B0...  Toys & Games
# 4                                                 []  Toys & Games
#
#                                         similar_item date  \
# 0                                                NaN  NaN
# 1                                                NaN  NaN
# 2                                                NaN  NaN
# 3   class="a-bordered a-horizontal-stripes  a-spa...  NaN
# 4                                                NaN  NaN
#
#                                                price        asin  \
# 0                                                NaN  0000191639
# 1  .a-box-inner{background-color:#fff}#alohaBuyBo...  0004950763
# 2  .a-box-inner{background-color:#fff}#alohaBuyBo...  0005069491
# 3                                             $24.95  0004983289
# 4                                              $4.92  0006466222
#
#                                             imageURL  \
# 0  ['https://images-na.ssl-images-amazon.com/imag...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                      imageURLHighRes details
# 0  ['https://images-na.ssl-images-amazon.com/imag...     NaN
# 1                                                 []     NaN
# 2                                                 []     NaN
# 3                                                 []     NaN
# 4                                                 []     NaN

# %%
display(hasbro_df)
# Out:
#                                                  category tech1  \
# 703     ['Toys & Games', 'Arts & Crafts', 'Drawing & P...   NaN
# 1966             ['Toys & Games', 'Games', 'Board Games']   NaN
# 1972             ['Toys & Games', 'Games', 'Board Games']   NaN
# 1981             ['Toys & Games', 'Games', 'Board Games']   NaN
# 1987             ['Toys & Games', 'Games', 'Board Games']   NaN
# ...                                                   ...   ...
# 633373                  ['Toys & Games', 'Grown-Up Toys']   NaN
# 633374           ['Toys & Games', 'Games', 'Board Games']   NaN
# 633376           ['Toys & Games', 'Games', 'Board Games']   NaN
# 633379           ['Toys & Games', 'Games', 'Board Games']   NaN
# 633393  ['Toys & Games', 'Stuffed Animals & Plush Toys...   NaN
#
#                                               description  fit  \
# 703                                                    []  NaN
# 1966    ["Exclusive for Yahtzee high-rollers! A posh n...  NaN
# 1972    ["You're the commander of the fleet when you p...  NaN
# 1981    ['', "Run, little mice, run! Many people playe...  NaN
# 1987    ['If you loved playing the Candy Land board ga...  NaN
# ...                                                   ...  ...
# 633373                          ['Hasbro Speak Out Game']  NaN
# 633374  ['The game is easy to set up, easy to learn, a...  NaN
# 633376  ['This fun version of the Operation game combi...  NaN
# 633379  ['Players put their charm, quick thinking, and...  NaN
# 633393  ["Do you remember Puppy Surprise from the 1990...  NaN
#
#                                                     title  \
# 703     My Little Pony JUMBO Coloring &amp; Activity B...
# 1966                        Hasbro Yahtzee Deluxe Edition
# 1972                                           Battleship
# 1981    Mouse Trap Board Game For Kids Ages 6 and Up (...
# 1987    Hasbro 04700 Candy Land Kingdom of Sweet Adven...
# ...                                                   ...
# 633373                             Speak Out Game English
# 633374                  DreamWorks Trolls in Trouble Game
# 633376                  Operation Game: Star Wars Edition
# 633379                                     Snake Oil Game
# 633393  1991 PUPPY SURPRISE Vintage Original Collectib...
#
#                                                  also_buy tech2   brand  \
# 703                                                    []   NaN  Hasbro
# 1966                                                   []   NaN  Hasbro
# 1972                                                   []   NaN  Hasbro
# 1981    ['B01JF1VRL0', 'B019NDGDIW', 'B00000DMFM', 'B0...   NaN  Hasbro
# 1987    ['B00000DMF6', 'B00D8STBHY', 'B076HK9H7Z', 'B0...   NaN  Hasbro
# ...                                                   ...   ...     ...
# 633373  ['B01LZ6SZLC', 'B01NCLQAJG', 'B01MSNC5GZ', 'B0...   NaN  Hasbro
# 633374                                                 []   NaN  Hasbro
# 633376                                                 []   NaN  Hasbro
# 633379                                                 []   NaN  Hasbro
# 633393                                                 []   NaN  Hasbro
#
#                                                   feature  \
# 703     ['My Little Pony', 'JUMBO Coloring & Activity ...
# 1966            ['One or more players.', 'Ages 8 and up']
# 1972    ['Classic naval warfare game', "Look for your ...
# 1981    ['CLASSIC MOUSE TRAP GAMEPLAY: Do you remember...
# 1987    ["CLASSIC BEGINNER GAME: Do you remember playi...
# ...                                                   ...
# 633373                                                 []
# 633374  ["It's the Trouble game featuring Dreamworks T...
# 633376  ['Classic Operation game meets the Star Wars U...
# 633379  ['Fun party game', "Customer profile changes a...
# 633393  ['Hasbro 1991 Original Puppy Surprise', "Guess...
#
#                                                      rank  \
# 703     ['>#1,114,331 in Toys & Games (See Top 100 in ...
# 1966    ['>#271,605 in Toys & Games (See Top 100 in To...
# 1972    ['>#510,892 in Toys & Games (See Top 100 in To...
# 1981    ['>#615 in Toys & Games (See Top 100 in Toys &...
# 1987    ['>#97 in Toys & Games (See Top 100 in Toys & ...
# ...                                                   ...
# 633373                           13,893 in Toys & Games (
# 633374  ['>#18,264 in Toys & Games (See Top 100 in Toy...
# 633376  ['>#6,247 in Toys & Games (See Top 100 in Toys...
# 633379  ['>#8,438 in Toys & Games (See Top 100 in Toys...
# 633393  ['>#1,644,068 in Toys & Games (See Top 100 in ...
#
#                                                 also_view      main_cat  \
# 703                                                    []  Toys & Games
# 1966    ['B00TLEMRKM', 'B00B28GVLG', 'B01FP9ZZ78', 'B0...  Toys & Games
# 1972    ['B06Y1N3PTX', 'B00C0ULS3G', 'B00CPGZ9E4', 'B0...  Toys & Games
# 1981    ['B003B1WF7Q', 'B004S6SQZI', 'B01ISKSRK8', 'B0...  Toys & Games
# 1987    ['B00000DMF6', 'B01C3J4DNU', 'B00D7OAOYI', 'B0...  Toys & Games
# ...                                                   ...           ...
# 633373  ['B01M5KEOI6', 'B01IWALX00', 'B01LYWNWXU', 'B0...  Toys & Games
# 633374                                                 []  Toys & Games
# 633376                                                 []  Toys & Games
# 633379                                                 []  Toys & Games
# 633393                                                 []  Toys & Games
#
#                                              similar_item date    price  \
# 703      class="a-bordered a-horizontal-stripes  a-spa...  NaN    $4.02
# 1966     class="a-bordered a-horizontal-stripes  a-spa...  NaN  $114.69
# 1972     class="a-bordered a-horizontal-stripes  a-spa...  NaN   $49.88
# 1981     class="a-bordered a-horizontal-stripes  a-spa...  NaN   $24.00
# 1987     class="a-bordered a-horizontal-stripes  a-spa...  NaN   $12.99
# ...                                                   ...  ...      ...
# 633373                                                NaN  NaN      NaN
# 633374   class="a-bordered a-horizontal-stripes  a-spa...  NaN   $14.98
# 633376   class="a-bordered a-horizontal-stripes  a-spa...  NaN   $15.19
# 633379   class="a-bordered a-horizontal-stripes  a-spa...  NaN   $13.23
# 633393                                                NaN  NaN      NaN
#
#               asin                                           imageURL  \
# 703     1593941064                                                 []
# 1966    B00000DMBL                                                 []
# 1972    B00000DMBB                                                 []
# 1981    B00000DMFD  ['https://images-na.ssl-images-amazon.com/imag...
# 1987    B00000DMF5  ['https://images-na.ssl-images-amazon.com/imag...
# ...            ...                                                ...
# 633373  B01HH0NTDA  ['https://images-na.ssl-images-amazon.com/imag...
# 633374  B01HH0NT26  ['https://images-na.ssl-images-amazon.com/imag...
# 633376  B01HH0NTMQ  ['https://images-na.ssl-images-amazon.com/imag...
# 633379  B01HH0NTOE  ['https://images-na.ssl-images-amazon.com/imag...
# 633393  B01HH2Q520  ['https://images-na.ssl-images-amazon.com/imag...
#
#                                           imageURLHighRes  \
# 703                                                    []
# 1966                                                   []
# 1972                                                   []
# 1981    ['https://images-na.ssl-images-amazon.com/imag...
# 1987    ['https://images-na.ssl-images-amazon.com/imag...
# ...                                                   ...
# 633373  ['https://images-na.ssl-images-amazon.com/imag...
# 633374  ['https://images-na.ssl-images-amazon.com/imag...
# 633376  ['https://images-na.ssl-images-amazon.com/imag...
# 633379  ['https://images-na.ssl-images-amazon.com/imag...
# 633393  ['https://images-na.ssl-images-amazon.com/imag...
#
#                                                   details
# 703                                                   NaN
# 1966                                                   {}
# 1972                                                   {}
# 1981                                                   {}
# 1987                                                   {}
# ...                                                   ...
# 633373  {'\n    Product Dimensions: \n    ': '2 x 10.5...
# 633374                                                 {}
# 633376                                                 {}
# 633379                                                 {}
# 633393                                                 {}
#
# [6899 rows x 19 columns]
